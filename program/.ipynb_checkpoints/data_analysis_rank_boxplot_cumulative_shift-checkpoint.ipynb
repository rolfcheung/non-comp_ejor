# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# Set notebook display
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# import data analysis libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def rank_boxplot_cumulative_shift(data, labels, reference_rank_index = 0):
    '''
    
    Data is a DataFrame
    The costructure of data is as following: columns are cities
                                             rows are different parameters
                                             elements in data are pefermance ranks
    
    labels is the legend displaying on the cumulative rank shift figure, do not include the reference rank row
    
    reference_rank_index is the index of the reference rank in the data, and is a int
    
    import nescessary modules:
    
        # Set notebook display
        # %matplotlib inline
        from IPython.display import set_matplotlib_formats
        set_matplotlib_formats('retina')
    
        # import data analysis libraries

        import pandas as pd
        import matplotlib.pyplot as plt
        import seaborn as sns
    '''
    
    # rank boxplot
    fig = plt.figure(num = 1, figsize = (20, 8))
    ax1 = plt.subplot(121)
    
    font = {'family' : 'serif', 
            'color'  : 'k', 
            'weight' : 'normal', 
            'size'   : 8
           } 
    
    meanprops = dict(marker = '^', markerfacecolor='none',
                     markersize=4, linestyle='none', linewidth = 0.5)
    
    sns.set_style('ticks')
    
    _, boxplot = data.boxplot(ax = ax1, grid = False,
                              showmeans = False, meanprops = meanprops, return_type = 'both')
    
    ax1.set_xticklabels(list(data.columns),rotation = 'vertical', 
                        fontdict=font, ha = 'center', va = 'baseline')
    ax1.set_ylabel("Low-carbon Performance Rank", fontdict=font, ha = 'center')
   
    
    # generate a new DataFrame for store the rank shift with respect to the reference rank. Here, 
    # the reference rank is the rank without consideration of thresholds
    def rank_shift(data, reference_rank_row_index):
        rank_shift_data_frame = pd.DataFrame(index=data.index, columns=data.columns)
        
        rank_shift_data_frame.drop(reference_rank_row_index, inplace = True)
        
        rows, columns = rank_shift_data_frame.shape
        
        for column in range(columns):
            for row in range(rows):
                rank_shift_data_frame.iloc[row, column] = data.iloc[row+1, column] - data.iloc[0, column]
                
        return rank_shift_data_frame

    rank_shift_data = rank_shift(data, data.index[reference_rank_index])
    
    # cumulative rank shift and average rank shift plot
    ax2 = plt.subplot(122)
    par = ax2.twinx()
    
    average_rank_shift = rank_shift_data.sum()/len(rank_shift_data.index)
    

    
    stacked_bar = rank_shift_data.T.plot.bar(ax = ax2, stacked=True, colormap='tab20')
    average_rank_shift.plot.line(ax = par, color = 'k', linestyle='--', label = 'Average Rank Shift')
    
    ax2.set_xticklabels(list(rank_shift_data.T.index), fontdict=font)
    ax2.set_ylabel("Cumulative Rank Shift", fontdict=font, ha = 'center')
    
    par.set_ylabel("Average Rank Shift", fontdict=font, ha = 'center')
    
    ax2.legend(loc='lower left', shadow=True, fontsize='small', labels = labels, ncol=5)
    
    par.legend(loc = 'best', fontsize = 'small')
    
    plt.tight_layout()
    plt.show()
    
    return fig

# %% [markdown]
# # equal_thres

# %%
equal_thres_phi03_path = os.path.join(os.path.abspath('..'), 'results', 
                                       'outranking_matrix','equal_threshod_00_10_phi0.3', 'total_rank.csv')

if os.path.exists(equal_thres_phi03_path):
    print('File path: ', equal_thres_phi03_path)
else:
    print('Check the path')

    
equal_thres_phi03_data = pd.read_csv(equal_thres_phi03_path, index_col = 0)

equal_thres_phi03_data.head()
# Out:
# File path:  /Users/rolf/Downloads/noncomp/rank/results/outranking_matrix/equal_threshod_00_10_phi0.3/total_rank.csv
#               equal_threshold_00  equal_threshold_01  equal_threshold_02  \
# Beijing                        2                   2                   1
# Tianjin                       29                  29                  29
# Shijiazhuang                  33                  34                  34
# Qinhuangdao                   27                  26                  24
# Baoding                       36                  37                  35
#
#               equal_threshold_03  equal_threshold_04  equal_threshold_05  \
# Beijing                        1                   1                   1
# Tianjin                       31                  33                  34
# Shijiazhuang                  32                  29                  28
# Qinhuangdao                   24                  21                  19
# Baoding                       30                  30                  31
#
#               equal_threshold_06  equal_threshold_07  equal_threshold_08  \
# Beijing                      1.0                   1                   1
# Tianjin                     35.0                  37                  36
# Shijiazhuang                29.0                  28                  27
# Qinhuangdao                 18.0                  16                  18
# Baoding                     33.0                  32                  33
#
#               equal_threshold_09  equal_threshold_10
# Beijing                        1                   1
# Tianjin                       32                  35
# Shijiazhuang                  29                  30
# Qinhuangdao                   22                  21
# Baoding                       30                  32

# %%
equal_thres_phi03_data_trans = equal_thres_phi03_data.T

equal_thres_phi03_data_trans.head()
# Out:
#                     Beijing  Tianjin  Shijiazhuang  Qinhuangdao  Baoding  \
# equal_threshold_00      2.0     29.0          33.0         27.0     36.0
# equal_threshold_01      2.0     29.0          34.0         26.0     37.0
# equal_threshold_02      1.0     29.0          34.0         24.0     35.0
# equal_threshold_03      1.0     31.0          32.0         24.0     30.0
# equal_threshold_04      1.0     33.0          29.0         21.0     30.0
#
#                     Taiyuan  Hohhot  Shenyang  Dalian  Changchun   ...    \
# equal_threshold_00     40.0    13.0      31.0     9.0       28.0   ...
# equal_threshold_01     40.0    12.0      33.0     8.0       31.0   ...
# equal_threshold_02     40.0    14.0      33.0     7.0       32.0   ...
# equal_threshold_03     40.0    15.0      35.0     5.0       34.0   ...
# equal_threshold_04     40.0    15.0      32.0     5.0       35.0   ...
#
#                     Guilin  Haikou  Chongqing  Chengdu  Guiyang  Zunyi  \
# equal_threshold_00    39.0     7.0       38.0      8.0     10.0   37.0
# equal_threshold_01    39.0     9.0       38.0      7.0     11.0   35.0
# equal_threshold_02    38.0    13.0       39.0     11.0      8.0   36.0
# equal_threshold_03    37.0    13.0       39.0      8.0     11.0   36.0
# equal_threshold_04    37.0    13.0       39.0      7.0     11.0   34.0
#
#                     Kunming  Xian  Lanzhou  Urumqi
# equal_threshold_00      5.0  24.0     23.0    16.0
# equal_threshold_01      6.0  22.0     24.0    14.0
# equal_threshold_02      9.0  21.0     25.0    12.0
# equal_threshold_03     10.0  18.0     25.0     9.0
# equal_threshold_04     10.0  19.0     26.0     8.0
#
# [5 rows x 40 columns]

# %%
labels_eqth = [r'$EqTh-1$',r'$EqTh-2$', r'$EqTh-3$', r'$EqTh-4$',
               r'$EqTh-5$', r'$EqTh-6$', r'$EqTh-7$', r'$EqTh-8$',
               r'$EqTh-9$', r'$EqTh-10$']

# %%
fig_eqth = rank_boxplot_cumulative_shift(equal_thres_phi03_data_trans, labels_eqth)

# %%
fig_eqth.savefig('../results/fig_equal_threshod.pdf')

# %% [markdown]
# # indifference_threhold_00_10_phi0.3
# ## total_rank_pre_10

# %%
indiff_thres_phi03_path = os.path.join(os.path.abspath('..'), 'results', 
                                                       'outranking_matrix','indifference_threhold_00_10_phi0.3', 
                                                       'total_rank_pre_10.csv')

if os.path.exists(indiff_thres_phi03_path):
    print('File path: ', indiff_thres_phi03_path)
else:
    print('Check the path')

indiff_thres_phi03_data = pd.read_csv(indiff_thres_phi03_path, index_col = 0)

indiff_thres_phi03_data.head()
# Out:
# File path:  /Users/rolf/Downloads/noncomp/rank/results/outranking_matrix/indifference_threhold_00_10_phi0.3/total_rank_pre_10.csv
#               thres_ref  indiff_threshold_00  indiff_threshold_01  \
# Beijing               2                   16                   12
# Tianjin              29                   40                   39
# Shijiazhuang         33                   38                   38
# Qinhuangdao          27                   35                   35
# Baoding              36                   37                   37
#
#               indiff_threshold_02  indiff_threshold_03  indiff_threshold_04  \
# Beijing                        11                    9                    9
# Tianjin                        39                   39                   39
# Shijiazhuang                   38                   38                   38
# Qinhuangdao                    35                   35                   35
# Baoding                        37                   37                   36
#
#               indiff_threshold_05  indiff_threshold_06  indiff_threshold_07  \
# Beijing                         8                    7                    7
# Tianjin                        39                   39                   39
# Shijiazhuang                   38                   38                   38
# Qinhuangdao                    35                   35                   34
# Baoding                        36                   36                   36
#
#               indiff_threshold_08  indiff_threshold_09  indiff_threshold_10
# Beijing                         6                    5                    5
# Tianjin                        39                   39                   39
# Shijiazhuang                   38                   38                   38
# Qinhuangdao                    33                   31                   31
# Baoding                        36                   36                   36

# %%
indiff_thres_phi03_data_trans = indiff_thres_phi03_data.T

indiff_thres_phi03_data_trans.head()
# Out:
#                      Beijing  Tianjin  Shijiazhuang  Qinhuangdao  Baoding  \
# thres_ref                  2       29            33           27       36
# indiff_threshold_00       16       40            38           35       37
# indiff_threshold_01       12       39            38           35       37
# indiff_threshold_02       11       39            38           35       37
# indiff_threshold_03        9       39            38           35       37
#
#                      Taiyuan  Hohhot  Shenyang  Dalian  Changchun   ...    \
# thres_ref                 40      13        31       9         28   ...
# indiff_threshold_00       39      27        36      28         34   ...
# indiff_threshold_01       40      27        36      28         34   ...
# indiff_threshold_02       40      26        36      27         34   ...
# indiff_threshold_03       40      26        36      27         34   ...
#
#                      Guilin  Haikou  Chongqing  Chengdu  Guiyang  Zunyi  \
# thres_ref                39       7         38        8       10     37
# indiff_threshold_00      20       9         25        3        8     12
# indiff_threshold_01      22      10         26        3        7     14
# indiff_threshold_02      24       9         28        3        8     14
# indiff_threshold_03      24      10         29        3        8     14
#
#                      Kunming  Xian  Lanzhou  Urumqi
# thres_ref                  5    24       23      16
# indiff_threshold_00        6     7        5       1
# indiff_threshold_01        5     8        6       1
# indiff_threshold_02        5    10        6       2
# indiff_threshold_03        5    11        6       2
#
# [5 rows x 40 columns]

# %%
labels_indiff_thres_phi03 = [r'$IndiffTh-\phi\frac{1}{3}-0$', r'$IndiffTh-\phi\frac{1}{3}-1$',r'$IndiffTh-\phi\frac{1}{3}-2$', 
                             r'$IndiffTh-\phi\frac{1}{3}-3$', r'$IndiffTh-\phi\frac{1}{3}-4$', r'$IndiffTh-\phi\frac{1}{3}-5$', 
                             r'$IndiffTh-\phi\frac{1}{3}-6$', r'$IndiffTh-\phi\frac{1}{3}-7$', r'$IndiffTh-\phi\frac{1}{3}-8$', 
                             r'$IndiffTh-\phi\frac{1}{3}-9$', r'$IndiffTh-\phi\frac{1}{3}-10$']

# %%
fig_indiff_thres_phi03 = rank_boxplot_cumulative_shift(indiff_thres_phi03_data_trans, labels_indiff_thres_phi03)

# %%
fig_indiff_thres_phi03.savefig('../results/fig_indiff_thres_phi03_pre_10.pdf')

# %% [markdown]
# # latter 10

# %%
indiff_thres_phi03_latter_path = os.path.join(os.path.abspath('..'), 'results', 
                                                       'outranking_matrix','indifference_threhold_00_10_phi0.3', 
                                                       'total_rank_latter_10.csv')

if os.path.exists(indiff_thres_phi03_latter_path):
    print('File path: ', indiff_thres_phi03_latter_path)
else:
    print('Check the path')

indiff_thres_phi03_latter_data = pd.read_csv(indiff_thres_phi03_latter_path, index_col = 0)

indiff_thres_phi03_latter_data.head()
# Out:
# File path:  /Users/rolf/Downloads/noncomp/rank/results/outranking_matrix/indifference_threhold_00_10_phi0.3/total_rank_latter_10.csv
#               thres_ref  indiff_threshold_00  indiff_threshold_01  \
# Beijing               2                    5                  3.0
# Tianjin              29                   39                 39.0
# Shijiazhuang         33                   38                 38.0
# Qinhuangdao          27                   31                 31.0
# Baoding              36                   36                 35.5
#
#               indiff_threshold_02  indiff_threshold_03  indiff_threshold_04  \
# Beijing                         2                    2                    2
# Tianjin                        39                   39                   38
# Shijiazhuang                   37                   37                   35
# Qinhuangdao                    31                   30                   28
# Baoding                        34                   34                   34
#
#               indiff_threshold_05  indiff_threshold_06  indiff_threshold_07  \
# Beijing                         2                    2                    2
# Tianjin                        38                   38                   37
# Shijiazhuang                   36                   35                   35
# Qinhuangdao                    28                   26                   25
# Baoding                        33                   32                   33
#
#               indiff_threshold_08  indiff_threshold_09  indiff_threshold_10
# Beijing                         2                    1                    1
# Tianjin                        36                   36                   35
# Shijiazhuang                   31                   30                   30
# Qinhuangdao                    25                   24                   21
# Baoding                        34                   33                   32

# %%
indiff_thres_phi03_latter_data_trans = indiff_thres_phi03_latter_data.T

indiff_thres_phi03_latter_data_trans.head()
# Out:
#                      Beijing  Tianjin  Shijiazhuang  Qinhuangdao  Baoding  \
# thres_ref                2.0     29.0          33.0         27.0     36.0
# indiff_threshold_00      5.0     39.0          38.0         31.0     36.0
# indiff_threshold_01      3.0     39.0          38.0         31.0     35.5
# indiff_threshold_02      2.0     39.0          37.0         31.0     34.0
# indiff_threshold_03      2.0     39.0          37.0         30.0     34.0
#
#                      Taiyuan  Hohhot  Shenyang  Dalian  Changchun   ...    \
# thres_ref               40.0    13.0      31.0     9.0       28.0   ...
# indiff_threshold_00     40.0    24.0      37.0    25.0       35.0   ...
# indiff_threshold_01     40.0    24.0      37.0    25.0       33.0   ...
# indiff_threshold_02     40.0    21.0      38.0    25.0       33.0   ...
# indiff_threshold_03     40.0    18.0      36.0    22.0       32.0   ...
#
#                      Guilin  Haikou  Chongqing  Chengdu  Guiyang  Zunyi  \
# thres_ref              39.0     7.0       38.0      8.0     10.0   37.0
# indiff_threshold_00    27.0    10.0       33.0      3.0      8.0   17.0
# indiff_threshold_01    27.0    10.0       35.5      4.0      8.0   21.0
# indiff_threshold_02    27.0    10.0       36.0      5.0      9.0   23.0
# indiff_threshold_03    31.0    10.0       38.0      6.0      9.0   25.0
#
#                      Kunming  Xian  Lanzhou  Urumqi
# thres_ref                5.0  24.0     23.0    16.0
# indiff_threshold_00      7.0  12.0      9.0     2.0
# indiff_threshold_01      7.0  12.0     11.0     2.0
# indiff_threshold_02      7.0  13.0     11.0     3.0
# indiff_threshold_03      8.0  13.0     11.0     4.0
#
# [5 rows x 40 columns]

# %%
labels_indiff_thres_phi03_latter = [r'$IndiffTh-\phi\frac{1}{3}-0$', 
                                    r'$IndiffTh-\phi\frac{1}{3}-1$',
                                    r'$IndiffTh-\phi\frac{1}{3}-2$',
                                    r'$IndiffTh-\phi\frac{1}{3}-3$', 
                                    r'$IndiffTh-\phi\frac{1}{3}-4$', 
                                    r'$IndiffTh-\phi\frac{1}{3}-5$',
                                    r'$IndiffTh-\phi\frac{1}{3}-6$', 
                                    r'$IndiffTh-\phi\frac{1}{3}-7$', 
                                    r'$IndiffTh-\phi\frac{1}{3}-8$',
                                    r'$IndiffTh-\phi\frac{1}{3}-9$', 
                                    r'$IndiffTh-\phi\frac{1}{3}-10$']

# %%
fig_indiff_thres_phi03_latter = rank_boxplot_cumulative_shift(indiff_thres_phi03_latter_data_trans, 
                                                              labels_indiff_thres_phi03_latter)

# %%
fig_indiff_thres_phi03_latter.savefig('../results/fig_indiff_thres_phi03_latter_10.pdf')

# %% [markdown]
# # indifference_threhold_00_10_phi0.6
# ## pre_10

# %%
indiff_thres_phi06_path = os.path.join(os.path.abspath('..'), 'results', 
                                                       'outranking_matrix','indifference_threhold_00_10_phi0.6', 
                                                       'total_rank_pre_10.csv')

if os.path.exists(indiff_thres_phi06_path):
    print('File path: ', indiff_thres_phi06_path)
else:
    print('Check the path')

indiff_thres_phi06_data = pd.read_csv(indiff_thres_phi06_path, index_col = 0)

indiff_thres_phi06_data.head()
# Out:
# File path:  /Users/rolf/Downloads/noncomp/rank/results/outranking_matrix/indifference_threhold_00_10_phi0.6/total_rank_pre_10.csv
#               thres_ref  indiff_threshold_00  indiff_threshold_01  \
# Beijing               2                    1                    1
# Tianjin              29                    4                    7
# Shijiazhuang         33                    8                    8
# Qinhuangdao          27                    5                    6
# Baoding              36                   12                   12
#
#               indiff_threshold_02  indiff_threshold_03  indiff_threshold_04  \
# Beijing                       1.0                    1                    1
# Tianjin                       9.0                    9                    8
# Shijiazhuang                  8.0                    8                    9
# Qinhuangdao                   6.0                    6                    6
# Baoding                      11.0                   15                   15
#
#               indiff_threshold_05  indiff_threshold_06  indiff_threshold_07  \
# Beijing                         1                    1                    1
# Tianjin                         8                   10                   10
# Shijiazhuang                   11                   11                   12
# Qinhuangdao                     7                    7                    7
# Baoding                        18                   18                   18
#
#               indiff_threshold_08  indiff_threshold_09  indiff_threshold_10
# Beijing                         1                    1                    1
# Tianjin                        10                   10                   10
# Shijiazhuang                   12                   13                   13
# Qinhuangdao                     7                    8                    8
# Baoding                        18                   18                   19

# %%
indiff_thres_phi06_data.equals(indiff_thres_phi03_data)
# Out:
# False

# %%
indiff_thres_phi06_data_trans = indiff_thres_phi06_data.T

indiff_thres_phi06_data_trans.head()
# Out:
#                      Beijing  Tianjin  Shijiazhuang  Qinhuangdao  Baoding  \
# thres_ref                2.0     29.0          33.0         27.0     36.0
# indiff_threshold_00      1.0      4.0           8.0          5.0     12.0
# indiff_threshold_01      1.0      7.0           8.0          6.0     12.0
# indiff_threshold_02      1.0      9.0           8.0          6.0     11.0
# indiff_threshold_03      1.0      9.0           8.0          6.0     15.0
#
#                      Taiyuan  Hohhot  Shenyang  Dalian  Changchun   ...    \
# thres_ref               40.0    13.0      31.0     9.0       28.0   ...
# indiff_threshold_00     19.0     3.0      13.0     2.0       16.0   ...
# indiff_threshold_01     19.0     5.0      13.0     2.0       18.0   ...
# indiff_threshold_02     19.0     5.0      15.0     3.0       18.0   ...
# indiff_threshold_03     19.0     5.0      16.0     4.0       20.0   ...
#
#                      Guilin  Haikou  Chongqing  Chengdu  Guiyang  Zunyi  \
# thres_ref              39.0     7.0       38.0      8.0     10.0   37.0
# indiff_threshold_00    37.0    29.0       40.0     23.0     33.0   39.0
# indiff_threshold_01    38.0    28.0       40.0     22.0     33.0   39.0
# indiff_threshold_02    38.0    27.0       40.0     21.0     32.5   39.0
# indiff_threshold_03    38.0    27.0       40.0     18.0     33.0   39.0
#
#                      Kunming  Xian  Lanzhou  Urumqi
# thres_ref                5.0  24.0     23.0    16.0
# indiff_threshold_00     32.0  38.0     36.0    34.0
# indiff_threshold_01     32.0  37.0     36.0    34.0
# indiff_threshold_02     31.0  37.0     36.0    34.0
# indiff_threshold_03     31.0  37.0     36.0    32.0
#
# [5 rows x 40 columns]

# %%
labels_indiff_thres_phi06 = [r'$IndiffTh-\phi\frac{1}{6}-0$',
                             r'$IndiffTh-\phi\frac{1}{6}-1$',
                             r'$IndiffTh-\phi\frac{1}{6}-2$',
                             r'$IndiffTh-\phi\frac{1}{6}-3$',
                             r'$IndiffTh-\phi\frac{1}{6}-4$',
                             r'$IndiffTh-\phi\frac{1}{6}-5$',
                             r'$IndiffTh-\phi\frac{1}{6}-6$',
                             r'$IndiffTh-\phi\frac{1}{6}-7$',
                             r'$IndiffTh-\phi\frac{1}{6}-8$',
                             r'$IndiffTh-\phi\frac{1}{6}-9$',
                             r'$IndiffTh-\phi\frac{1}{6}-10$']

# %%
fig_indiff_thres_phi06 = rank_boxplot_cumulative_shift(indiff_thres_phi06_data_trans, labels_indiff_thres_phi06)

# %%
fig_indiff_thres_phi06.savefig('../results/fig_indiff_thres_phi06_pre_10.pdf')

# %% [markdown]
# # latter 10

# %%
indiff_thres_phi06_latter_path = os.path.join(os.path.abspath('..'), 'results', 
                                                       'outranking_matrix','indifference_threhold_00_10_phi0.6', 
                                                       'total_rank_latter_10.csv')

if os.path.exists(indiff_thres_phi06_latter_path):
    print('File path: ', indiff_thres_phi06_latter_path)
else:
    print('Check the path')

indiff_thres_phi06_latter_data = pd.read_csv(indiff_thres_phi06_latter_path, index_col = 0)

indiff_thres_phi06_latter_data.head()
# Out:
# File path:  /Users/rolf/Downloads/noncomp/rank/results/outranking_matrix/indifference_threhold_00_10_phi0.6/total_rank_latter_10.csv
#               thres_ref  indiff_threshold_00  indiff_threshold_01  \
# Beijing               2                    1                  1.0
# Tianjin              29                   10                 12.0
# Shijiazhuang         33                   13                 14.5
# Qinhuangdao          27                    8                  9.0
# Baoding              36                   19                 20.0
#
#               indiff_threshold_02  indiff_threshold_03  indiff_threshold_04  \
# Beijing                       1.0                    1                  1.0
# Tianjin                      12.0                   16                 18.5
# Shijiazhuang                 16.5                   19                 23.0
# Qinhuangdao                  10.0                   11                 11.0
# Baoding                      22.5                   28                 28.0
#
#               indiff_threshold_05  indiff_threshold_06  indiff_threshold_07  \
# Beijing                         1                    1                    1
# Tianjin                        23                   26                   28
# Shijiazhuang                   25                   28                   29
# Qinhuangdao                    13                   14                   18
# Baoding                        32                   33                   31
#
#               indiff_threshold_08  indiff_threshold_09  indiff_threshold_10
# Beijing                       1.0                    1                    1
# Tianjin                      29.0                   32                   35
# Shijiazhuang                 30.0                   30                   30
# Qinhuangdao                  20.0                   20                   21
# Baoding                      33.0                   33                   32

# %%
indiff_thres_phi06_latter_data_trans = indiff_thres_phi06_latter_data.T

indiff_thres_phi06_latter_data_trans.head()
# Out:
#                      Beijing  Tianjin  Shijiazhuang  Qinhuangdao  Baoding  \
# thres_ref                2.0     29.0          33.0         27.0     36.0
# indiff_threshold_00      1.0     10.0          13.0          8.0     19.0
# indiff_threshold_01      1.0     12.0          14.5          9.0     20.0
# indiff_threshold_02      1.0     12.0          16.5         10.0     22.5
# indiff_threshold_03      1.0     16.0          19.0         11.0     28.0
#
#                      Taiyuan  Hohhot  Shenyang  Dalian  Changchun   ...    \
# thres_ref               40.0    13.0      31.0     9.0       28.0   ...
# indiff_threshold_00     28.0     5.0      17.0     4.0       23.0   ...
# indiff_threshold_01     31.0     5.0      17.0     4.0       26.0   ...
# indiff_threshold_02     33.0     5.0      20.0     4.0       28.0   ...
# indiff_threshold_03     34.0     6.0      24.0     5.0       30.0   ...
#
#                      Guilin  Haikou  Chongqing  Chengdu  Guiyang  Zunyi  \
# thres_ref              39.0     7.0       38.0      8.0     10.0   37.0
# indiff_threshold_00    39.0    18.0       40.0     12.0     31.0   38.0
# indiff_threshold_01    39.0    18.0       40.0     10.0     30.0   38.0
# indiff_threshold_02    39.0    16.5       40.0      9.0     30.0   38.0
# indiff_threshold_03    39.0    12.0       40.0      8.0     25.0   38.0
#
#                      Kunming  Xian  Lanzhou  Urumqi
# thres_ref                5.0  24.0     23.0    16.0
# indiff_threshold_00     30.0  37.0     35.0    27.0
# indiff_threshold_01     25.0  37.0     35.0    23.0
# indiff_threshold_02     21.0  37.0     34.0    18.0
# indiff_threshold_03     18.0  37.0     33.0    14.0
#
# [5 rows x 40 columns]

# %%
labels_indiff_thres_phi06_latter = [r'$IndiffTh-\phi\frac{1}{6}-0$',
                                    r'$IndiffTh-\phi\frac{1}{6}-1$',
                                    r'$IndiffTh-\phi\frac{1}{6}-2$',
                                    r'$IndiffTh-\phi\frac{1}{6}-3$',
                                    r'$IndiffTh-\phi\frac{1}{6}-4$',
                                    r'$IndiffTh-\phi\frac{1}{6}-5$',
                                    r'$IndiffTh-\phi\frac{1}{6}-6$',
                                    r'$IndiffTh-\phi\frac{1}{6}-7$',
                                    r'$IndiffTh-\phi\frac{1}{6}-8$',
                                    r'$IndiffTh-\phi\frac{1}{6}-9$',
                                    r'$IndiffTh-\phi\frac{1}{6}-10$']

# %%
fig_indiff_thres_phi06_latter = rank_boxplot_cumulative_shift(indiff_thres_phi06_latter_data_trans, 
                                                              labels_indiff_thres_phi06_latter)

# %%
fig_indiff_thres_phi06_latter.savefig('../results/fig_indiff_thres_phi06_latter_10.pdf')

# %% [markdown]
# # preference_threshod_00_10_phi0.3

# %%
pref_thres_phi03_path = os.path.join(os.path.abspath('..'), 'results', 
                                     'outranking_matrix','preference_threshod_00_10_phi0.3',
                                     'total_rank.csv')

if os.path.exists(pref_thres_phi03_path):
    print('File path: ', pref_thres_phi03_path)
else:
    print('Check the path')

pref_thres_phi03_data = pd.read_csv(pref_thres_phi03_path, index_col = 0)

pref_thres_phi03_data.head()
# Out:
# File path:  /Users/rolf/Downloads/noncomp/rank/results/outranking_matrix/preference_threshod_00_10_phi0.3/total_rank.csv
#               thres_ref  pref_threshold_00  pref_threshold_01  \
# Beijing               2                  1                1.0
# Tianjin              29                 33               37.0
# Shijiazhuang         33                 28               30.0
# Qinhuangdao          27                 25               25.0
# Baoding              36                 29               28.0
#
#               pref_threshold_02  pref_threshold_03  pref_threshold_04  \
# Beijing                       1                  1                  1
# Tianjin                      37                 38                 38
# Shijiazhuang                 31                 33                 35
# Qinhuangdao                  25                 29                 27
# Baoding                      30                 30                 30
#
#               pref_threshold_05  pref_threshold_06  pref_threshold_07  \
# Beijing                       1                  2                  2
# Tianjin                      39                 38                 39
# Shijiazhuang                 34                 36                 36
# Qinhuangdao                  27                 28                 28
# Baoding                      31                 33                 33
#
#               pref_threshold_08  pref_threshold_09  pref_threshold_10
# Beijing                       2                  3                  5
# Tianjin                      39                 39                 39
# Shijiazhuang                 36                 38                 38
# Qinhuangdao                  30                 31                 31
# Baoding                      33                 33                 36

# %%
pref_thres_phi03_data_trans = pref_thres_phi03_data.T

pref_thres_phi03_data_trans.head()
# Out:
#                    Beijing  Tianjin  Shijiazhuang  Qinhuangdao  Baoding  \
# thres_ref              2.0     29.0          33.0         27.0     36.0
# pref_threshold_00      1.0     33.0          28.0         25.0     29.0
# pref_threshold_01      1.0     37.0          30.0         25.0     28.0
# pref_threshold_02      1.0     37.0          31.0         25.0     30.0
# pref_threshold_03      1.0     38.0          33.0         29.0     30.0
#
#                    Taiyuan  Hohhot  Shenyang  Dalian  Changchun   ...    \
# thres_ref             40.0    13.0      31.0     9.0       28.0   ...
# pref_threshold_00     39.0    11.0      36.0     7.0       34.0   ...
# pref_threshold_01     39.0    11.0      35.0     7.0       33.0   ...
# pref_threshold_02     39.0    13.0      36.0     7.0       34.0   ...
# pref_threshold_03     39.0    15.0      36.0     9.0       35.0   ...
#
#                    Guilin  Haikou  Chongqing  Chengdu  Guiyang  Zunyi  \
# thres_ref            39.0     7.0       38.0      8.0     10.0   37.0
# pref_threshold_00    37.0    15.0       40.0      8.0      9.0   31.0
# pref_threshold_01    36.0    15.0       40.0      8.0      9.5   31.0
# pref_threshold_02    35.0    15.0       40.0      8.0     10.0   28.0
# pref_threshold_03    32.0    13.0       40.0      7.0     10.0   28.0
#
#                    Kunming  Xian  Lanzhou  Urumqi
# thres_ref              5.0  24.0     23.0    16.0
# pref_threshold_00      6.0  20.0     21.0    10.0
# pref_threshold_01      6.0  18.0     20.0     9.5
# pref_threshold_02      6.0  16.0     18.0     9.0
# pref_threshold_03      6.0  17.0     16.0     8.0
#
# [5 rows x 40 columns]

# %%
labels_pref_thres_phi03 = [r'$PrefTh-\phi\frac{1}{3}-0$',
                           r'$PrefTh-\phi\frac{1}{3}-1$',
                           r'$PrefTh-\phi\frac{1}{3}-2$',
                           r'$PrefTh-\phi\frac{1}{3}-3$',
                           r'$PrefTh-\phi\frac{1}{3}-4$',
                           r'$PrefTh-\phi\frac{1}{3}-5$',
                           r'$PrefTh-\phi\frac{1}{3}-6$',
                           r'$PrefTh-\phi\frac{1}{3}-7$',
                           r'$PrefTh-\phi\frac{1}{3}-8$',
                           r'$PrefTh-\phi\frac{1}{3}-9$',
                           r'$PrefTh-\phi\frac{1}{3}-10$']

# %%
fig_pref_thres_phi03 = rank_boxplot_cumulative_shift(pref_thres_phi03_data_trans,
                                                     labels_pref_thres_phi03)

# %%
fig_pref_thres_phi03.savefig('../results/fig_pref_thres_phi03.pdf')

# %% [markdown]
# # preference_threshod_00_10_phi0.6

# %%
pref_thres_phi06_path = os.path.join(os.path.abspath('..'), 'results', 
                                     'outranking_matrix','preference_threshod_00_10_phi0.6',
                                     'total_rank.csv')

if os.path.exists(pref_thres_phi06_path):
    print('File path: ', pref_thres_phi06_path)
else:
    print('Check the path')

pref_thres_phi06_data = pd.read_csv(pref_thres_phi06_path, index_col = 0)

pref_thres_phi06_data.head()
# Out:
# File path:  /Users/rolf/Downloads/noncomp/rank/results/outranking_matrix/preference_threshod_00_10_phi0.6/total_rank.csv
#               thres_ref  equal_threshold_00  equal_threshold_01  \
# Beijing               2                   1                   1
# Tianjin              29                  33                  34
# Shijiazhuang         33                  28                  28
# Qinhuangdao          27                  25                  24
# Baoding              36                  29                  29
#
#               equal_threshold_02  equal_threshold_03  equal_threshold_04  \
# Beijing                        1                   1                   1
# Tianjin                       30                  32                  31
# Shijiazhuang                  28                  28                  26
# Qinhuangdao                   23                  23                  19
# Baoding                       29                  29                  28
#
#               equal_threshold_05  equal_threshold_06  equal_threshold_07  \
# Beijing                        1                   1                   1
# Tianjin                       31                  27                  24
# Shijiazhuang                  22                  21                  18
# Qinhuangdao                   17                  12                  10
# Baoding                       27                  28                  29
#
#               equal_threshold_08  equal_threshold_09  equal_threshold_10
# Beijing                        1                   1                   1
# Tianjin                       20                  12                  10
# Shijiazhuang                  12                  13                  13
# Qinhuangdao                   10                   9                   8
# Baoding                       28                  23                  19

# %%
pref_thres_phi06_data_trans = pref_thres_phi06_data.T

pref_thres_phi06_data_trans.head()
# Out:
#                     Beijing  Tianjin  Shijiazhuang  Qinhuangdao  Baoding  \
# thres_ref                 2       29            33           27       36
# equal_threshold_00        1       33            28           25       29
# equal_threshold_01        1       34            28           24       29
# equal_threshold_02        1       30            28           23       29
# equal_threshold_03        1       32            28           23       29
#
#                     Taiyuan  Hohhot  Shenyang  Dalian  Changchun   ...    \
# thres_ref                40      13        31       9         28   ...
# equal_threshold_00       39      11        36       7         34   ...
# equal_threshold_01       39       9        35       6         30   ...
# equal_threshold_02       37       9        35       6         31   ...
# equal_threshold_03       37       8        35       5         30   ...
#
#                     Guilin  Haikou  Chongqing  Chengdu  Guiyang  Zunyi  \
# thres_ref               39       7         38        8       10     37
# equal_threshold_00      37      15         40        8        9     31
# equal_threshold_01      37      16         40        8       10     36
# equal_threshold_02      39      15         40        7       12     36
# equal_threshold_03      39      16         40        7       13     36
#
#                     Kunming  Xian  Lanzhou  Urumqi
# thres_ref                 5    24       23      16
# equal_threshold_00        6    20       21      10
# equal_threshold_01        7    23       25      11
# equal_threshold_02        8    24       27      10
# equal_threshold_03        9    27       26      10
#
# [5 rows x 40 columns]

# %%
labels_pref_thres_phi06 = [r'$PrefTh-\phi\frac{1}{6}-0$',
                           r'$PrefTh-\phi\frac{1}{6}-1$',
                           r'$PrefTh-\phi\frac{1}{6}-2$',
                           r'$PrefTh-\phi\frac{1}{6}-3$',
                           r'$PrefTh-\phi\frac{1}{6}-4$',
                           r'$PrefTh-\phi\frac{1}{6}-5$',
                           r'$PrefTh-\phi\frac{1}{6}-6$',
                           r'$PrefTh-\phi\frac{1}{6}-7$',
                           r'$PrefTh-\phi\frac{1}{6}-8$',
                           r'$PrefTh-\phi\frac{1}{6}-9$',
                           r'$PrefTh-\phi\frac{1}{6}-10$']

# %%
fig_pref_thres_phi06 = rank_boxplot_cumulative_shift(pref_thres_phi06_data_trans,
                                                     labels_pref_thres_phi06)

# %%
fig_pref_thres_phi06.savefig('../results/fig_pref_thres_phi06.pdf')
